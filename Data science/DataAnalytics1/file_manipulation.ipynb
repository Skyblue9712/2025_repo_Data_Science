# %%
import os

# %%
with open('myfile.txt','r') as file:
    print(file.read())
# Out:
# aaj kuch toofani karte h let's check
# jo jeeta wahi sikandar
# mai kal ki chinta nhi kerta

# %%
with open('myfile.txt','r') as file:
    print(file.readlines())
# Out:
# ["aaj kuch toofani karte h let's check\n", 'jo jeeta wahi sikandar\n', 'mai kal ki chinta nhi kerta\n']

# %%
with open('newfile.txt','w') as file:
    print(file.write('My name is Bond, James Bond'))
# Out:
# 27

# %%
# rw+
# append

# %%
with open('createfile.txt','w+') as file:
    file.write('Here is your new txt new for check')
    print(file.read())

# %%
with open('book.txt','a') as file:
    file.write('\nThere is my book')
