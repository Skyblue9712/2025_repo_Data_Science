# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\DataAnalytics1'

# %%
os.mkdir('dir1')

# %%
os.chdir('mydir')

# %%
os.mkdir('dir2')

# %%
os.mkdir('dir3')

# %%
os.getcwd()
# Out:
# 'd:\\DataAnalytics1\\mydir'

# %%
os.listdir()
# Out:
# ['dir2', 'dir3']

# %%
os.listdir('../../')
# Out:
# ['$RECYCLE.BIN',
#  'DataAnalytics',
#  'DataAnalytics1',
#  'Python basic',
#  'System Volume Information']

# %%
os.listdir('../../Python basic') # ../ for moving outside of current folder
# Out:
# ['basic_programs.ipynb',
#  'conditions.ipynb',
#  'datatypes.ipynb',
#  'Dictionary.ipynb',
#  'functions.ipynb',
#  'inheritance.ipynb',
#  'intro.ipynb',
#  'lambda.ipynb',
#  'list.ipynb',
#  'list_comprehension.ipynb',
#  'loop.ipynb',
#  'oops.ipynb',
#  'operators.ipynb',
#  'set.ipynb',
#  'strings.ipynb',
#  'task29Aug.ipynb',
#  'task30Aug.ipynb',
#  'task31Aug.ipynb',
#  'tuple.ipynb']

# %%
os.listdir('../')
# Out:
# ['.git',
#  'dir1',
#  'file_handling.ipynb',
#  'HandlingDatasets.ipynb',
#  'mydir',
#  'numpy.ipynb']

# %%
os.chdir('../')

# %%
os.getcwd()
# Out:
# 'd:\\DataAnalytics1'

# %%
with open('myfile.txt', 'r') as file:
    print(file.read())
# Out:
# aaj kuch toofani karte h let's check
