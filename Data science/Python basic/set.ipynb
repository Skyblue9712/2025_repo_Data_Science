# %%
A = { 1, 2, 3, 4 }
B = { 3, 4, 5, 6 }
C = { 6, 7, 8, 9 }

# %%
{3, 54, 6, 8, 2, 3, 6 }
# Out:
# {2, 3, 6, 8, 54}

# %%
# union
print(A | B)
print(A.union(B))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %%
# intersection
print(A & B)
print(A.intersection(C))
# Out:
# {3, 4}
# set()

# %%
type({})
# Out:
# dict

# %%
# difference
print(A - B)
print(A.difference(B))
# Out:
# {1, 2}
# {1, 2}

# %%
D = {2, 3}

# %%
D.issubset(A)
# Out:
# True

# %%
A.issuperset(D)
# Out:
# True

# %%
A.isdisjoint(B)
# Out:
# False

# %%
A.isdisjoint(C)
# Out:
# True

# %%
A.symmetric_difference(B)
# Out:
# {1, 2, 5, 6}

# %%
A.update(B)

# %%
A
# Out:
# {1, 2, 3, 4, 5, 6}
