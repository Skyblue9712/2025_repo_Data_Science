# %%
print('hello python')
# Out:
# hello python

# %%
a = 56
print(a)
# Out:
# 56

# %%
b, c = 10, 20
b
# Out:
# 10

# %%
print(b, c)
# Out:
# 10 20

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print('something')
# Out:
# something

# %% [markdown]
# # Welcome to Python
# ##### Here we are learning python basics
