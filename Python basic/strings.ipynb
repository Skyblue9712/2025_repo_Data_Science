# %%
dialogue = "This is Sparta"

# %%
# Indexing
dialogue[2]
# Out:
# 'i'

# %%
dialogue[-3]
# Out:
# 'r'

# %%
dialogue.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dialogue.index('x')
#
# ValueError: substring not found

# %%
dialogue.rindex('s')
# Out:
# 6

# %%
dialogue
# Out:
# 'This is Sparta'

# %%
dialogue[20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dialogue[20]
#
# IndexError: string index out of range

# %%
dialogue.index('x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dialogue.index('x')
#
# ValueError: substring not found

# %%
dialogue.find('x')
# Out:
# -1

# %%
# slicing
dialogue[0:4]
# Out:
# 'This'

# %%
len(dialogue)
# Out:
# 14

# %%
dialogue[0:]
# Out:
# 'This is Sparta'

# %%
dialogue[-6:]
# Out:
# 'Sparta'

# %%
dialogue[-4:-6]
# Out:
# ''

# %%
dialogue[-4:-7:-1]
# Out:
# 'apS'

# %%
dialogue[ : :-1]
# Out:
# 'atrapS si sihT'

# %%
dialogue[ : : 2]
# Out:
# 'Ti sSat'

# %%
n = int(input('enter the number'))

print( int(str(n)[::-1]) )
# Out:
# 64

# %%
name = "madan mohan malviya"

name.find('m', 1)
# Out:
# 6

# %%
lastFound = -1
while True:
    lastFound = name.find('m', lastFound+1)
    if lastFound != -1:
        print(lastFound)
    else:
        break
# Out:
# 0
# 6
# 12

# %%
dialogue.count('a')
# Out:
# 2

# %%
dialogue.split()
# Out:
# ['This', 'is', 'Sparta']

# %%
url="https://www.google.com/search?q=3+digit+armstrong+number&rlz=1C1VDKB_enIN1146IN1146&oq=3+digit+arms&gs_lcrp=EgZjaHJvbWUqCQgAEEUYOxiABDIJCAAQRRg7GIAEMgYIARBFGDkyBwgCEAAYgAQyCAgDEAAYFhgeMggIBBAAGBYYHjIICAUQABgWGB4yCAgGEAAYFhgeMggIBxAAGBYYHjIICAgQABgWGB4yCAgJEAAYFhge0gEIMzU2NmowajGoAgCwAgA&sourceid=chrome&ie=UTF-8"

url.split('/')
# Out:
# ['https:',
#  '',
#  'www.google.com',
#  'search?q=3+digit+armstrong+number&rlz=1C1VDKB_enIN1146IN1146&oq=3+digit+arms&gs_lcrp=EgZjaHJvbWUqCQgAEEUYOxiABDIJCAAQRRg7GIAEMgYIARBFGDkyBwgCEAAYgAQyCAgDEAAYFhgeMggIBBAAGBYYHjIICAUQABgWGB4yCAgGEAAYFhgeMggIBxAAGBYYHjIICAgQABgWGB4yCAgJEAAYFhge0gEIMzU2NmowajGoAgCwAgA&sourceid=chrome&ie=UTF-8']

# %%
'  abc '.strip()
# rstrip()
# lstrip()
# Out:
# 'abc'

# %%
'__xyz____'.strip('_')
# Out:
# 'xyz'

# %%
'-$__xy$z_$$-'.strip('_$-')
# Out:
# 'xy$z'

# %%
dialogue.replace(' ', '_')
# Out:
# 'This_is_Sparta'

# %%
dialogue.replace('s', 't')
# Out:
# 'Thit it Sparta'

# %%
dialogue.replace?
# Out:
# Signature: dialogue.replace(old, new, count=-1, /)
# Docstring:
# Return a copy with all occurrences of substring old replaced by new.
#
#   count
#     Maximum number of occurrences to replace.
#     -1 (the default value) means replace all occurrences.
#
# If the optional argument count is given, only the first count occurrences are
# replaced.
# Type:      builtin_function_or_method

# %%
# formatting functions
print(dialogue.lower())
print(dialogue.upper())
print(dialogue.title())
print(dialogue.capitalize())
print(dialogue.swapcase())
print(dialogue.casefold())
# Out:
# this is sparta
# THIS IS SPARTA
# This Is Sparta
# This is sparta
# tHIS IS sPARTA
# this is sparta

# %%
# conditional checks
print(dialogue.startswith('This'))
print(dialogue.endswith('This'))
print(dialogue.islower())
print(dialogue.isupper())
print(dialogue.istitle())
# Out:
# True
# False
# False
# False
# False

# %%
'abc'.isalpha()
# Out:
# True

# %%
'3456'.isnumeric()
# Out:
# True

# %%
'abc123.'.isalnum()
# Out:
# False

# %%
'abc'.center(20, '&')
# Out:
# '&&&&&&&&abc&&&&&&&&&'

# %%
'abc'.rjust(10, '$')
# Out:
# '$$$$$$$abc'

# %%
'abc'.ljust(10, '$')
# Out:
# 'abc$$$$$$$'

# %%
dialogue2 = 'I   am       Batman'

# %%
mylist = dialogue2.split()

# %%
' '.join(mylist)
# Out:
# 'I am Batman'

# %%
word1 = 'A_B_C_D_E_F'
# ABCDEF

# %%
word1[::2]
# Out:
# 'ABCDEF'

# %%
myname = "Mubassir"
total = 0
for i in 'aeiou':
    print(myname.count(i))
    total += myname.count(i)
print('Total Vowels:', total)
# Out:
# 1
# 0
# 1
# 0
# 1
# Total Vowels: 3

# %%
# Practice Questions for String Functions in Python

# 1. Given a string, count the number of vowels in it.
# 2. Check if a string is a palindrome.
# 3. Replace all spaces in a string with underscores.
# 4. Find the first and last occurrence of a character in a string.
# 5. Given a string, print all unique characters.
# 6. Reverse the words in a sentence.
# 7. Check if a string contains only digits.
# 8. Convert the first character of each word to uppercase.
# 9. Remove all punctuation from a string.
# 10. Find the most frequent character in a string.

# You can use the variables 'dialogue', 'dialogue2', 'name', 'word1', etc., to practice these questions.
