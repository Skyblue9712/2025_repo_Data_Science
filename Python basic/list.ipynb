# %%
mylist = [1, 'hello', True, 45.3, None, print]

# %%
type(mylist)
# Out:
# list

# %%
mylist
# Out:
# [1,
#  'hello',
#  True,
#  45.3,
#  None,
#  <function print(*args, sep=' ', end='\n', file=None, flush=False)>]

# %%
movies = ['Jai Ho', 'Stree', 'Mann', 'It', 'Kyonki', 'Koyla']

# %%
len(movies)
# Out:
# 6

# %%
mat1 = [[1, 2, 3], [4, 5, 6]]

# %%
movies[2]
# Out:
# 'Mann'

# %%
movies[-3]
# Out:
# 'It'

# %%
movies.append('Sholey')

# %%
movies
# Out:
# ['Jai Ho', 'Stree', 'Mann', 'It', 'Kyonki', 'Koyla', 'Sholey']

# %%
mat1[0][0] + 1
# Out:
# 2

# %%
mat1
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
movies[2:6]
# Out:
# ['Mann', 'It', 'Kyonki', 'Koyla']

# %%
movies[2:-1]
# Out:
# ['Mann', 'It', 'Kyonki', 'Koyla']

# %%
# creating an empty list
empty = []

# %%
empty2 = list()

# %%
empty2
# Out:
# []

# %%
mat1.append(7)

# %%
mat1
# Out:
# [[1, 2, 3], [4, 5, 6], 7]

# %%
movies.insert(1, 'KGF')

# %%
movies
# Out:
# ['Jai Ho', 'KGF', 'Stree', 'Mann', 'It', 'Kyonki', 'Koyla', 'Sholey']

# %%
movies[1::]
# Out:
# ['KGF', 'Stree', 'Mann', 'It', 'Kyonki', 'Koyla', 'Sholey']

# %%
movies[::-1]
# Out:
# ['Sholey', 'Koyla', 'Kyonki', 'It', 'Mann', 'Stree', 'KGF', 'Jai Ho']

# %%
nums = [1, 2, 3]
nums.extend([4, 5, 6])
nums
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
movies.count('Koyla')
# Out:
# 1

# %%
nums.append(2)
nums
# Out:
# [1, 2, 3, 4, 5, 6, 2]

# %%
nums.count(2)
# Out:
# 2

# %%
movies + ['stree 2']
# Out:
# ['Jai Ho',
#  'KGF',
#  'Stree',
#  'Mann',
#  'It',
#  'Kyonki',
#  'Koyla',
#  'Sholey',
#  'stree 2']

# %%
fruits = ['apple', 'lichi']
fruits.extend('kiwi')

# %%
fruits
# Out:
# ['apple', 'lichi', 'k', 'i', 'w', 'i']

# %%
movies.index('Sholey')
# Out:
# 7

# %%
movies.pop()
# Out:
# 'Koyla'

# %%
movies
# Out:
# ['Jai Ho', 'KGF', 'Stree', 'Mann', 'It', 'Kyonki']

# %%
movies.remove('Mann')

# %%
movies
# Out:
# ['Jai Ho', 'KGF', 'Stree', 'It', 'Kyonki']

# %%
movies.reverse()

# %%
movies
# Out:
# ['Kyonki', 'It', 'Stree', 'KGF', 'Jai Ho']

# %%
movies.sort()

# %%
movies
# Out:
# ['It', 'Jai Ho', 'KGF', 'Kyonki', 'Stree']

# %%
movies.copy()
# Out:
# ['It', 'Jai Ho', 'KGF', 'Kyonki', 'Stree']

# %%
A = [1, 2, 3]
B = A.copy()

# %%
B.append(4)

# %%
B
# Out:
# [1, 2, 3, 4]

# %%
A
# Out:
# [1, 2, 3]

# %%
# list traversal

# %%
fruits = ['apple', 'grapes', 'kiwi', 'guava', 'lichi']

# %%
for f in fruits:
    print(f)
# Out:
# apple
# grapes
# kiwi
# guava
# lichi

# %%
nums = [3, 5, 7, 9, 5, 1, 2, 6, 8]
# multiply every element by 2
# print only even numbers

# %%
for i in nums:
    print(i*2)
# Out:
# 6
# 10
# 14
# 18
# 10
# 2
# 4
# 12
# 16

# %%
for i in nums:
    if i%2==0:
        print(i)
# Out:
# 2
# 6
# 8

# %%
for f in enumerate(fruits):
    print(f)
# Out:
# (0, 'apple')
# (1, 'grapes')
# (2, 'kiwi')
# (3, 'guava')
# (4, 'lichi')

# %%
for (i, f) in enumerate(fruits):
    print(i, f)
# Out:
# 0 apple
# 1 grapes
# 2 kiwi
# 3 guava
# 4 lichi

# %%
# print only elements on odd indexes
for (i, f) in enumerate(fruits):
    if i%2!=0:
        print(f)
# Out:
# grapes
# guava

# %%
sum(nums)
# Out:
# 46

# %%
max(nums)
# Out:
# 9

# %%
min(nums)
# Out:
# 1

# %%
# 10 practice questions based on list properties (independent, do not use existing variables)
# Focused on simple problem solving

# 1. Create a list called 'colors' with 5 color names. Print the list.

# 2. How many items are in the 'colors' list?

# 3. What are the first and last elements of the 'numbers' list?

# 4. What happens when you add the value 60 to the end of the 'numbers' list?

# 5. What is the result after removing the value 20 from the 'numbers' list?

# 6. What is the total of all values in the 'numbers' list?

# 7. What does the 'colors' list look like in reverse order?

# 8. What is the content of 'colors_copy' after copying the 'colors' list?

# 9. How does the 'colors' list appear when sorted alphabetically?

# 10. Which values in the 'numbers' list are even?
