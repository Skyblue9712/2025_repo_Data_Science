# %% [markdown]
# ### Datatypes in Python
# - Integer (int) Ex. +345, 0, -63
# - String (str) Ex. 'hello' , "buy"
# - Boolean (bool) Ex. True, False
# - Float (float) Ex. 4.345, -0.345
# - None

# %%
a = 345

# %%
type(a)
# Out:
# int

# %%
msg = 'hi'
type(msg)
# Out:
# str

# %%
isHungry=True
type(isHungry)
# Out:
# bool

# %%
multiline = """ line 1
line 2
line 3"""

# %%
multiline
# Out:
# ' line 1\nline 2\nline 3'

# %%
print(multiline)
# Out:
#  line 1
# line 2
# line 3

# %%
empty = None
type(empty)
# Out:
# NoneType

# %%
print(empty)
# Out:
# None

# %%
empty
