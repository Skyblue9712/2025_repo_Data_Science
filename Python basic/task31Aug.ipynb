# %%
word = "nice"

# %%
word
# Out:
# 'nice'

# %%
word[-2]
# Out:
# 'c'

# %%
word[1:4]
# Out:
# 'ice'

# %%
word[:4:2]
# Out:
# 'nc'

# %%
word[::-1]
# Out:
# 'ecin'

# %%
wordInput = input('Enter a word: ')

if wordInput == wordInput[::-1]:
    print(f"{wordInput} is a palindrome")
else:
    print(f"{wordInput} is not a palindrome")
# Out:
# repaper is a palindrome

# %%
message = "Good Morning"

message.find('o')
# Out:
# 1

# %%
message.rfind('o')
# Out:
# 6

# %%
''.join(set(message))
# Out:
# 'noM rGdgi'

# %%
message2 = "Hello, How are you?"

# %%
wordList = message2.split()
wordList
# Out:
# ['Hello,', 'How', 'are', 'you?']

# %%
' '.join(wordList[::-1])
# Out:
# 'you? are How Hello,'

# %%
'32456'.isnumeric()
# Out:
# True

# %%
message2.title()
# Out:
# 'Hello, How Are You?'

# %%
message2.replace(',', '').replace('?', '')
# Out:
# 'Hello How are you'

# %%
for ch in '.,?':
    message2 = message2.replace(ch, '')

# %%
message2
# Out:
# 'Hello How are you'

# %%
count = 0
mostfreq = ''
for i in message2:
    if message2.count(i) > count:
        count = message2.count(i)
        mostfreq = i

# %%
print(i, count)
# Out:
# u 3
