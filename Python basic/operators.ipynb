# %% [markdown]
# ## Arithmetic Operators

# %%
a, b = 345, 467

# %%
c = a+b
c
# Out:
# 812

# %%
456 / 53
# Out:
# 8.60377358490566

# %%
4/2
# Out:
# 2.0

# %%
# floor division
546 // 54
# Out:
# 10

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ## Assignment Operators

# %%
a
# Out:
# 345

# %%
a+=5

# %%
a
# Out:
# 350

# %% [markdown]
# ## Comparison Operators

# %%
a == 200
# Out:
# False

# %%
a > 200
# Out:
# True

# %%
a >= 350
# Out:
# True

# %%
a != 200
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
# and logical operator
True and False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False and True
# Out:
# True

# %%
not False and not False
# Out:
# True

# %%
not True and (False or True)
# Out:
# False

# %%
not (True and False) or True
# Out:
# True

# %%
not (True and False) or (True and not False) or True
# Out:
# True

# %%
'dabrabla' in 'abrakadabra'
# Out:
# False

# %%
input('enter your name')
# Out:
# 'Mubassir'

# %%
name = input('enter your name')

# %%
name
# Out:
# 'Lestrade'
