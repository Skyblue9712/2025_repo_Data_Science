# %%
a, b = 10, 20

# %%
c = a+b
print(c)
print(a)
print(b)
# Out:
# 30
# 10
# 20

# %%
num1 = int(input('enter first number'))
num2 = int(input('enter second number'))

# %%
print(num1, num2)
# Out:
# 34 76

# %%
num1 + num2
# Out:
# 110

# %%
m1 = int(input('enter marks 1'))
m2 = int(input('enter marks 2'))
m3 = int(input('enter marks 3'))

avg = (m1+m2+m3)/3

print(avg)
# Out:
# 52.333333333333336

# %%
'a-b-c'.split('-')
# Out:
# ['a', 'b', 'c']

# %%
[x, y, z] = input('enter three numbers').split()

# %%
# WAP to input radius print area of cirle
# WAP to take name as input and display name with greeting

# %%
radius = int(input('enter radius'))

area = 3.14 * radius ** 2

print(f'area of the circle is {area}')
# Out:
# area of the circle is 78.5

# %%
name = input('enter your name')
print(f'Sayonara {name}')
# Out:
# Sayonara raju

# %%
'ha'*4
# Out:
# 'hahahaha'

# %%
# WAP to print square root of a number

# %%
16 ** 0.5
# Out:
# 4.0

# %%
import random

# %%
random.random()
# Out:
# 0.2650746008412531

# %%
random.randint(10, 30)
# Out:
# 24

# %%
random.choice(['bgmi', 'coc', 'cod'])
# Out:
# 'cod'

# %%
random.choices(['bgmi', 'coc', 'cod', 'gta', 'pop', 'gow'], k=2)
# Out:
# ['bgmi', 'bgmi']

# %%
games = ['bgmi', 'coc', 'pop', 'gow']
random.shuffle(games)
games
# Out:
# ['bgmi', 'pop', 'coc', 'gow']

# %%
import math

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.cos(0)
# Out:
# 1.0

# %%
math.tan(90)
# Out:
# -1.995200412208242
